# %% [markdown]
# # Text Preprocess in Bahasa

# %% [markdown]
# **1. Import the Library**

# %%
# !pip install nltk
# !pip install emoji
# !pip install Sastrawi
# !pip install regex

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\win
# [nltk_data]     8\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
import re
import nltk
import emoji

# %%
pd.set_option('display.max_colwidth',500)

# %% [markdown]
# **2. Load Dataset**

# %%
dataraw = pd.read_excel('Hasil_Data_Crawling.xlsx')
data =pd.DataFrame(dataraw['text']) 
data
# Out:
#                                                                                                                                                                                                                                                                                                                                                        text
# 0     @n_akb31 @HitsIndonesia_ @rudeski83 Indonesia pastikan Vaksin Covid-19 aman dan halal\nEfek samping yang terjadi, hanya bersifat minor dan sementara. Efek samping yang sangat besar sangat jarang ditemui, kita selalu memonitor dan mengantisipasi semua keadaan ini. Vaksin juga dapat melindungi diri kita dan orang lain https://t.co/14J1swgGc5
# 1                                              Selamat siang #SobatKom, #Healthies, penyuntikan vaksin COVID-19 dimaksudkan untuk membentuk kekebalan tubuh kita dari potensi penularan virus. Terdapat beberapa hal yang boleh dan tidak boleh kamu lakukan sebelum dan sesudah vaksinasi COVID-19. Yuk, simak infografis berikut! https://t.co/swDKShu9VE
# 2                                            Selamat pagi #SobatKom\n\nIndonesia kembali menerima kiriman 6 juta dosis bahan baku (bulk) vaksin COVID-19 dari Sinovac pada 18 April 2021\n\nDengan kedatangan vaksin tahap ke-8 ini, Indonesia telah menerima 59,5 juta bahan baku vaksin dari Sinovac yang akan diproses Bio Farma https://t.co/DH3c7TenAO
# 3                                                                                                                        Hari ini bersama aparat Desa Barumbung melakukan Vaksin Covid 19 di Puskesmas Matakali,  Terima kasih untuk Kepala desa Barumbung dan aparatnya walaupun diriku tdk lolos seleksi ð
# ð¤­ð­ @ Puskesmas Matakali https://t.co/8
# 4                                                                                                                                                                                                                                                           Ketua MUI Kapuas : Pemberian Vaksin Covid-19 Tidak Membatalkan Puasa\n\nhttps://t.co/26TaIFtG1W
# ...                                                                                                                                                                                                                                                                                                                                                     ...
# 4946                                                                                                                                                                                                                                                            Investigasi terkait vaksin AstraZeneca tersebut sudah dilakukan:\n\nhttps://t.co/h2GjF1u4v3
# 4947                                                                                                                                                                         Pemkot Jaktim tetap laksanakan penyuntikan vaksin ke masyarakat selama Ramadan.\n\n#merahputihcom #vaksinasicovid19 #covid19 #vaksincovid19 #ramadan \nhttps://t.co/yKEtG1rvLI
# 4948                                                                                                                                                                                                                                                        Giliran Pegawai Disdukcapil Bener Meriah Lakukan Suntik Vaksin Covid-19 https://t.co/Qg6Mux0txP
# 4949                                                                                                                                                                                                                         Vaksinasi berguna untuk memutus mata rantai penyebaran Covid-19 #Vaksin #Vaksinasi #Covid19 #Kesehatan https://t.co/GTzJ7zuNYp
# 4950                                                                                       Menteri Agama Yaqut Cholil Qoumas mengatakan, salah satu syarat untuk mengikuti ibadah umrah di Arab Saudi adalah sudah disuntik Vaksin Covid-19 yang bersertifikat Organisasi Kesehatan Dunia (WHO).\n\nReposted from @_farrah_nabilah_ https://t.co/B1hq9yg7wQ
#
# [4951 rows x 1 columns]

# %% [markdown]
# **2. Character Removing**

# %%
def preproses(tweets) :
    tweets = tweets.encode('ascii','ignore').decode('utf-8')
    tweets = re.sub(r'[^\x00-\x7f]',r'',tweets)
    tweets = re.sub(r'[_(){}[]]+','',tweets)
    tweets = re.sub(r'@[A-Za-z0-9]+','',tweets)
    tweets = re.sub(r'#[A-Za-z0-9]+','',tweets)
    tweets = re.sub(r'_[A-Za-z0-9]+','',tweets)
    tweets = re.sub(r'-[A-Za-z0-9]+','',tweets)
    tweets = re.sub(r':[A-Za-z0-9]+','',tweets)
    tweets = re.sub(r'https?:\/\/\S+','',tweets)
    tweets = re.sub(r'\d+','',tweets)
    tweets = re.sub(r'@+','',tweets)
    tweets = re.sub(r':+','',tweets)
    tweets = re.sub(r',+','',tweets)
    tweets = re.sub(r'_+','',tweets)
    tweets = tweets.lower()
    allemot = [str for str in tweets]
    listemot = [x for x in allemot if x in emoji.UNICODE_EMOJI]
    tweets = ' '.join([str for str in tweets.split()if not any (y in str for str in listemot)])
    return tweets
data['text']= data['text'].apply(preproses)
data
# Out:
#                                                                                                                                                                                                                                                                                      text
# 0     indonesia pastikan vaksin covid aman dan halal efek samping yang terjadi hanya bersifat minor dan sementara. efek samping yang sangat besar sangat jarang ditemui kita selalu memonitor dan mengantisipasi semua keadaan ini. vaksin juga dapat melindungi diri kita dan orang lain
# 1                                  selamat siang penyuntikan vaksin covid dimaksudkan untuk membentuk kekebalan tubuh kita dari potensi penularan virus. terdapat beberapa hal yang boleh dan tidak boleh kamu lakukan sebelum dan sesudah vaksinasi covid. yuk simak infografis berikut!
# 2                                       selamat pagi indonesia kembali menerima kiriman juta dosis bahan baku (bulk) vaksin covid dari sinovac pada april dengan kedatangan vaksin tahap ke ini indonesia telah menerima juta bahan baku vaksin dari sinovac yang akan diproses bio farma
# 3                                                                                         hari ini bersama aparat desa barumbung melakukan vaksin covid di puskesmas matakali terima kasih untuk kepala desa barumbung dan aparatnya walaupun diriku tdk lolos seleksi puskesmas matakali
# 4                                                                                                                                                                                                                         ketua mui kapuas pemberian vaksin covid tidak membatalkan puasa
# ...                                                                                                                                                                                                                                                                                   ...
# 4946                                                                                                                                                                                                                      investigasi terkait vaksin astrazeneca tersebut sudah dilakukan
# 4947                                                                                                                                                                                                      pemkot jaktim tetap laksanakan penyuntikan vaksin ke masyarakat selama ramadan.
# 4948                                                                                                                                                                                                                 giliran pegawai disdukcapil bener meriah lakukan suntik vaksin covid
# 4949                                                                                                                                                                                                                         vaksinasi berguna untuk memutus mata rantai penyebaran covid
# 4950                                                                      menteri agama yaqut cholil qoumas mengatakan salah satu syarat untuk mengikuti ibadah umrah di arab saudi adalah sudah disuntik vaksin covid yang bersertifikat organisasi kesehatan dunia (who). reposted from
#
# [4951 rows x 1 columns]

# %% [markdown]
# **3. Stopword Removal**

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

text_stopwords = []
for index,row in data.iterrows ():
    text_stopwords.append(stopword.remove(row['text']))  
    
data['text'] = text_stopwords
data
# Out:
#                                                                                                                                                                                                                                      text
# 0     indonesia pastikan vaksin covid aman halal efek samping terjadi bersifat minor sementara. efek samping sangat besar sangat jarang ditemui selalu memonitor mengantisipasi semua keadaan ini. vaksin dapat melindungi diri dan orang
# 1                             selamat siang penyuntikan vaksin covid dimaksudkan membentuk kekebalan tubuh dari potensi penularan virus. terdapat beberapa yang dan boleh kamu lakukan dan vaksinasi covid. yuk simak infografis berikut!
# 2                                   selamat pagi indonesia menerima kiriman juta dosis bahan baku (bulk) vaksin covid sinovac april kedatangan vaksin tahap ini indonesia menerima juta bahan baku vaksin sinovac akan diproses bio farma
# 3                                                          hari bersama aparat desa barumbung melakukan vaksin covid puskesmas matakali terima kasih kepala desa barumbung aparatnya walaupun diriku tdk lolos seleksi puskesmas matakali
# 4                                                                                                                                                                               ketua mui kapuas pemberian vaksin covid membatalkan puasa
# ...                                                                                                                                                                                                                                   ...
# 4946                                                                                                                                                                            investigasi terkait vaksin astrazeneca tersebut dilakukan
# 4947                                                                                                                                                         pemkot jaktim tetap laksanakan penyuntikan vaksin masyarakat selama ramadan.
# 4948                                                                                                                                                                 giliran pegawai disdukcapil bener meriah lakukan suntik vaksin covid
# 4949                                                                                                                                                                               vaksinasi berguna memutus mata rantai penyebaran covid
# 4950                                           menteri agama yaqut cholil qoumas mengatakan salah satu syarat mengikuti ibadah umrah arab saudi sudah disuntik vaksin covid bersertifikat organisasi kesehatan dunia (who). reposted from
#
# [4951 rows x 1 columns]

# %% [markdown]
# **4. Stemming**

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory= StemmerFactory()
Stemmer = factory.create_stemmer()
Stemming = []

for index,row in data.iterrows():
    Stemming.append(Stemmer.stem(row['text']))
    
data ['text']=Stemming
data
# Out:
#                                                                                                                                                                                                           text
# 0     indonesia pasti vaksin covid aman halal efek samping jadi sifat minor sementara efek samping sangat besar sangat jarang temu selalu monitor antisipasi semua ada ini vaksin dapat lindung diri dan orang
# 1                                    selamat siang sunti vaksin covid maksud bentuk kebal tubuh dari potensi tular virus dapat beberapa yang dan boleh kamu laku dan vaksinasi covid yuk simak infografis ikut
# 2                      selamat pagi indonesia terima kirim juta dosis bahan baku bulk vaksin covid sinovac april datang vaksin tahap ini indonesia terima juta bahan baku vaksin sinovac akan proses bio farma
# 3                                            hari sama aparat desa barumbung laku vaksin covid puskesmas matakali terima kasih kepala desa barumbung aparat walaupun diri tdk lolos seleksi puskesmas matakali
# 4                                                                                                                                                               ketua mui kapuas beri vaksin covid batal puasa
# ...                                                                                                                                                                                                        ...
# 4946                                                                                                                                                            investigasi kait vaksin astrazeneca sebut laku
# 4947                                                                                                                                          pemkot jaktim tetap laksana sunti vaksin masyarakat lama ramadan
# 4948                                                                                                                                             gilir pegawai disdukcapil bener riah laku suntik vaksin covid
# 4949                                                                                                                                                              vaksinasi guna putus mata rantai sebar covid
# 4950                                       menteri agama yaqut cholil qoumas kata salah satu syarat ikut ibadah umrah arab saudi sudah suntik vaksin covid sertifikat organisasi sehat dunia who reposted from
#
# [4951 rows x 1 columns]

# %% [markdown]
# **5. Remove Dupicate**

# %%
def fungsi_ku(x):
  return list(dict.fromkeys(x))
daftar_ku = fungsi_ku(data['text'])
baru = pd.DataFrame(daftar_ku)
baru
# Out:
#                                                                                                                                                                                                              0
# 0     indonesia pasti vaksin covid aman halal efek samping jadi sifat minor sementara efek samping sangat besar sangat jarang temu selalu monitor antisipasi semua ada ini vaksin dapat lindung diri dan orang
# 1                                    selamat siang sunti vaksin covid maksud bentuk kebal tubuh dari potensi tular virus dapat beberapa yang dan boleh kamu laku dan vaksinasi covid yuk simak infografis ikut
# 2                      selamat pagi indonesia terima kirim juta dosis bahan baku bulk vaksin covid sinovac april datang vaksin tahap ini indonesia terima juta bahan baku vaksin sinovac akan proses bio farma
# 3                                            hari sama aparat desa barumbung laku vaksin covid puskesmas matakali terima kasih kepala desa barumbung aparat walaupun diri tdk lolos seleksi puskesmas matakali
# 4                                                                                                                                                               ketua mui kapuas beri vaksin covid batal puasa
# ...                                                                                                                                                                                                        ...
# 3435                                                                                                                                                            investigasi kait vaksin astrazeneca sebut laku
# 3436                                                                                                                                          pemkot jaktim tetap laksana sunti vaksin masyarakat lama ramadan
# 3437                                                                                                                                             gilir pegawai disdukcapil bener riah laku suntik vaksin covid
# 3438                                                                                                                                                              vaksinasi guna putus mata rantai sebar covid
# 3439                                       menteri agama yaqut cholil qoumas kata salah satu syarat ikut ibadah umrah arab saudi sudah suntik vaksin covid sertifikat organisasi sehat dunia who reposted from
#
# [3440 rows x 1 columns]
